# %%
import json
import pprint
import pandas as pd
import time
import lol_data_crawling_2

rank_name = 'diamond3'
# 브실골 / zofht5789
api_key = 'RGAPI-986aaf2a-dd0a-412e-a2e9-012a6df0c78b'
# key ~ 2020.08.11. 오후 2시
lol_data_crawling_2.call_rank_data_for_dia(rank_name, api_key, 172)
print("1단계 완료")
lol_data_crawling_2.get_accountid(rank_name, api_key)
print("2단계 완료")
lol_data_crawling_2.get_match_data(rank_name, api_key)
print("3단계 완료")
# Out:
# 1단계 완료
# 고유 accountId 수집시작
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# <class 'pandas.core.frame.DataFrame'>
# ...
