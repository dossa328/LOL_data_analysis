# %%
import json
import pprint
import pandas as pd
import time
import lol_data_crawling
# challenger, grandmaster, master

rank_name = 'master'
api_key = 'RGAPI-971144c7-8909-4eb7-93a6-3bffbf679d53'
# lol_data_crawling.call_rank_data(rank_name, api_key)
# lol_data_crawling.get_accountid(rank_name, api_key)
# lol_data_crawling.get_match_data(rank_name, api_key)
lol_data_crawling.get_final_data(rank_name, api_key)
# Out:
# MatchId(gameId)를 활용한 최종 경기 데이터 수집중
# 0
# MatchId(gameId)를 활용한 최종 경기 데이터 수집중
# 1
# MatchId(gameId)를 활용한 최종 경기 데이터 수집중
# 2
# MatchId(gameId)를 활용한 최종 경기 데이터 수집중
# 3
# MatchId(gameId)를 활용한 최종 경기 데이터 수집중
# 4
# MatchId(gameId)를 활용한 최종 경기 데이터 수집중
# 5
# MatchId(gameId)를 활용한 최종 경기 데이터 수집중
# 6
# MatchId(gameId)를 활용한 최종 경기 데이터 수집중
# 7
# MatchId(gameId)를 활용한 최종 경기 데이터 수집중
# 8
# MatchId(gameId)를 활용한 최종 경기 데이터 수집중
# 9
# MatchId(gameId)를 활용한 최종 경기 데이터 수집중
# 10
# MatchId(gameId)를 활용한 최종 경기 데이터 수집중
# 11
# MatchId(gameId)를 활용한 최종 경기 데이터 수집중
# 12
# MatchId(gameId)를 활용한 최종 경기 데이터 수집중
# 13
# MatchId(gameId)를 활용한 최종 경기 데이터 수집중
# 14
# MatchId(gameId)를 활용한 최종 경기 데이터 수집중
# 15
# MatchId(gameId)를 활용한 최종 경기 데이터 수집중
# 16
# MatchId(gameId)를 활용한 최종 경기 데이터 수집중
# 17
# MatchId(gameId)를 활용한 최종 경기 데이터 수집중
# 18
# MatchId(gameId)를 활용한 최종 경기 데이터 수집중
# 19
# MatchId(gameId)를 활용한 최종 경기 데이터 수집중
# 20
# MatchId(gameId)를 활용한 최종 경기 데이터 수집중
# 21
# MatchId(gameId)를 활용한 최종 경기 데이터 수집중
# 22
# MatchId(gameId)를 활용한 최종 경기 데이터 수집중
# 23
# ...
